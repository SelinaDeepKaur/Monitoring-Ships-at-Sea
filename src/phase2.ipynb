# %%
import pandas as pd
import os.path
from operator import itemgetter
import glob
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

# %%
df1 =  pd.read_csv("../concatFinal/Zone11_2012_01.csv", low_memory=False)

# %%
df2 =  pd.read_csv("../concatFinal/Zone11_2012_02.csv", low_memory=False)

# %%
df3 =  pd.read_csv("../concatFinal/Zone11_2012_03.csv", low_memory=False)

# %%
df4 = pd.read_csv("../concatFinal/Zone11_2012_04.csv", low_memory=False)

# %%
df5 = pd.read_csv("../concatFinal/Zone11_2012_05.csv", low_memory=False)

# %%
df6 = pd.read_csv("../concatFinal/Zone11_2012_06.csv", low_memory=False)

# %%
df7 = pd.read_csv("../concatFinal/Zone11_2012_07.csv", low_memory=False)

# %%
df8 = pd.read_csv("../concatFinal/Zone11_2012_08.csv", low_memory=False)

# %%
df9 = pd.read_csv("../concatFinal/Zone11_2012_09.csv", low_memory=False)

# %%
df10 = pd.read_csv("../concatFinal/Zone11_2012_10.csv", low_memory=False)

# %%
df11 = pd.read_csv("../concatFinal/Zone11_2012_11.csv", low_memory=False)

# %%
df12 = pd.read_csv("../concatFinal/Zone11_2012_12.csv", low_memory=False)

# %%
df = pd.concat([df1,df2,df3,df4,df5,df6,df7,df8])

# %%
del df["ReceiverType"]
del df["ReceiverID"]
del df["MMSI"]

# %%
df.describe().transpose()
# Out:
#                 count          mean           std           min           25%  \
# latitude   35615629.0  3.297715e+01  1.759205e+00 -8.968778e+01  3.270431e+01
# longitude  35615629.0 -1.180825e+02  8.773898e-01 -1.200000e+02 -1.184512e+02
# SOG        35615629.0  3.931707e+00  7.173502e+00  0.000000e+00  0.000000e+00
# COG        35615629.0  1.810525e+02  1.138228e+02  0.000000e+00  8.890000e+01
# Heading    35615629.0  3.363113e+02  1.811401e+02  0.000000e+00  1.610000e+02
# ROT        35615629.0  5.402295e+01  6.829407e+01  0.000000e+00  0.000000e+00
# Timestamp  35615629.0  1.337119e+09  6.102105e+06  1.325711e+09  1.331852e+09
# Status     35615629.0  2.606658e+00  4.998806e+00  0.000000e+00  0.000000e+00
# VoyageID   35615629.0  1.888694e+03  3.170946e+03  1.000000e+00  9.000000e+01
#
#                     50%           75%           max
# latitude   3.365564e+01  3.376755e+01  8.999904e+01
# longitude -1.182184e+02 -1.172334e+02 -1.140000e+02
# ...

# %%
df.plot.scatter(x='longitude', y='latitude', color = 'r' , figsize=(10,10), alpha=0.1, s=0.1)

# %%
df_temp = df[df["latitude"] == 89.999045]

# %%
df_temp = df[df["VoyageID"] == 228]

# %%
df_temp.shape
# Out:
# (34106, 9)

# %%
df_temp.plot.scatter(x='latitude', y='longitude', color = 'r' , figsize=(7,7))

# %%
plt.show()

# %% [markdown]
# fig showing outlier in case of voyage id = 228

# %%
df_temp.plot.scatter(x='Timestamp', y='longitude', color = 'r' , figsize=(10,10))
df_temp.plot.scatter(x='Timestamp', y='latitude', color = 'b' , figsize=(10,10))

# %%
plt.show()

# %% [markdown]
# The above plot shows outlier for Voyage Id = 228

# %%
df_temp1 = df[df["latitude"] == -89.687782]

# %%
df_temp1 = df[df["VoyageID"] == 6136]

# %%
df_temp1.shape
# Out:
# (16463, 9)

# %%
df_temp1.plot.scatter(x='Timestamp', y='longitude', color = 'r' , figsize=(10,10))
df_temp1.plot.scatter(x='Timestamp', y='latitude', color = 'b' , figsize=(10,10))
plt.show()

# %%
df_temp1.plot.scatter(x='latitude', y='longitude', color = 'b' , figsize=(7,7))
plt.show()

# %% [markdown]
# fig showing outlier in case of voyage id = 6136

# %%
df = df[df["latitude"] >= 30]

# %%
df = df[df["latitude"] <= 40]

# %%
df = df[df["longitude"] >= -119]

# %%
df = df[df["longitude"] <= -115.5]

# %%
df.shape
# Out:
# (28093896, 9)

# %%
test = pd.concat([df9,df10,df11,df12])

# %%
test = test[test["latitude"] >= 30]

# %%
test = test[test["latitude"] <= 40]

# %%
test = test[test["longitude"] >= -119]

# %%
test = test[test["longitude"] <= -115.5]

# %%
test.shape
# Out:
# (15904199, 12)

# %%
test.describe().transpose()
# Out:
#                 count          mean           std           min           25%  \
# latitude   18631947.0  3.333819e+01  6.990341e-01  3.000002e+01  3.271198e+01
# longitude  18631947.0 -1.180810e+02  7.423413e-01 -1.200000e+02 -1.184485e+02
# SOG        18631947.0  3.112814e+00  8.261344e+00  0.000000e+00  0.000000e+00
# COG        18631947.0  1.794901e+02  1.159237e+02  0.000000e+00  7.710000e+01
# Heading    18631947.0  3.438394e+02  1.813751e+02  0.000000e+00  1.810000e+02
# ROT        18631947.0  4.850994e+01  6.580908e+01  0.000000e+00  0.000000e+00
# Timestamp  18631947.0  1.351311e+09  2.994400e+06  1.346472e+09  1.348695e+09
# Status     18631947.0  2.746751e+00  4.985800e+00  0.000000e+00  0.000000e+00
# VoyageID   18631947.0  1.143971e+03  1.742072e+03  1.000000e+00  8.900000e+01
# MMSI       18631947.0  3.666961e+08  8.247292e+07  0.000000e+00  3.387850e+08
#
#                     50%           75%           max
# latitude   3.369252e+01  3.376775e+01  3.935143e+01
# ...

# %%
dff = pd.core.frame.DataFrame
latt = dff({'count' : test.groupby( [ "latitude"] ).size()}).reset_index()
latt_sorted = latt.sort_values(by=["latitude","count"], ascending=False)
latt_sorted
# Out:
#           latitude  count
# 2191323  89.736367      1
# 2191322  89.518720      1
# 2191321  89.493220      1
# 2191320  82.340182      1
# 2191319  75.938383      1
# 2191318  68.760553      1
# 2191317  67.815543      1
# 2191316  67.507492      1
# 2191315  64.730038      1
# 2191314  61.876833      1
# 2191313  61.739193      1
# 2191312  57.920823      1
# 2191311  55.923035      1
# 2191310  55.660193      1
# 2191309  55.225007      1
# 2191308  54.943765      1
# 2191307  54.497663      1
# 2191306  54.379927      1
# 2191305  52.807653      1
# 2191304  52.335598      1
# 2191303  51.730753      1
# 2191302  49.293303      1
# 2191301  49.290922      1
# 2191300  48.322507      1
# 2191299  47.516553      1
# 2191298  46.702167      5
# 2191297  46.702000     10
# 2191296  46.701902      1
# 2191295  46.701882      1
# 2191294  46.701875      3
# ...            ...    ...
# 29      -12.415063      1
# 28      -12.862893      1
# 27      -13.323825      1
# ...

# %%
df_temp = df[df["latitude"] == 89.736367]

# %%
df.shape
# Out:
# (33509013, 9)

# %%
test.shape
# Out:
# (18631947, 12)

# %%
latitude_linear_reg_test_X = test[['SOG', 'COG', 'Heading', 'ROT','Timestamp','Status',
       'VoyageID']]
latitude_linear_reg_test_Y = test[['latitude']]

# %%
latitude_linear_reg_train_X = df[['SOG', 'COG', 'Heading', 'ROT','Timestamp','Status',
       'VoyageID']]
latitude_linear_reg_train_Y = df[['latitude']]

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.linear_model import LinearRegression
latitude_final_columns = list(latitude_linear_reg_train_X.columns)

# %%
#latitude_linear_reg_train_X, latitude_linear_reg_test_X ,
#latitude_linear_reg_train_Y, latitude_linear_reg_test_Y = train_test_split(latitude_train_X, 
                                        #latitude_train_Y, test_size=0.2, random_state=23)

# Linear Regression model initialization (basic)
latitude_linear_regression = LinearRegression()

# Training the Linear Regression Model
latitude_linear_regression.fit(latitude_linear_reg_train_X, latitude_linear_reg_train_Y)

# Using the model to predict the test dataset
latitude_linear_reg_predicted_Y = latitude_linear_regression.predict(latitude_linear_reg_test_X)

# The coefficients of the linear equation aX1 + bX2 + cX3 + ... = Y
print('Coefficients (a,b,c,..) : ', [(x,y) for x,y in zip(latitude_final_columns, latitude_linear_regression.coef_)])

# The mean squared error of the linear regression model's predictions
print("Mean squared error: %.5f" % mean_squared_error(latitude_linear_reg_test_Y, latitude_linear_reg_predicted_Y))

# Variance of the prediction
print('Variance : %.5f' % r2_score(latitude_linear_reg_test_Y, latitude_linear_reg_predicted_Y))
# Out:
# Coefficients (a,b,c,..) :  [('SOG', array([ -1.36481442e-02,  -2.16999429e-04,  -2.63459421e-05,
#          6.40444508e-04,   1.23642225e-09,   1.19318923e-02,
#         -1.05062873e-05]))]
# Mean squared error: 0.40836
# Variance : 0.02149

# %%
longitude_linear_reg_train_X = df[['SOG', 'COG', 'Heading', 'ROT','Timestamp','Status',
       'VoyageID']]
longitude_linear_reg_train_Y = df[['longitude']]

# %%
longitude_linear_reg_test_X = test[['SOG', 'COG', 'Heading', 'ROT','Timestamp','Status',
       'VoyageID']]
longitude_linear_reg_test_Y = test[['longitude']]

# %%
longitude_final_columns = list(longitude_linear_reg_train_X.columns)

# %%
#longitude_linear_reg_train_X, longitude_linear_reg_test_X , longitude_linear_reg_train_Y, longitude_linear_reg_test_Y = 
#train_test_split(longitude_train_X, longitude_train_Y, test_size=0.2, random_state=23)

# Linear Regression model initialization (basic)
longitude_linear_regression = LinearRegression()

# Training the Linear Regression Model
longitude_linear_regression.fit(longitude_linear_reg_train_X, longitude_linear_reg_train_Y)

# Using the model to predict the test dataset
longitude_linear_reg_predicted_Y = longitude_linear_regression.predict(longitude_linear_reg_test_X)

# The coefficients of the linear equation aX1 + bX2 + cX3 + ... = Y
print('Coefficients (a,b,c,..) : ', [(x,y) for x,y in zip(longitude_final_columns, longitude_linear_regression.coef_)])

# The mean squared error of the linear regression model's predictions
print("Mean squared error: %.5f" % mean_squared_error(longitude_linear_reg_test_Y, longitude_linear_reg_predicted_Y))

# Variance of the prediction
print('Variance : %.5f' % r2_score(longitude_linear_reg_test_Y, longitude_linear_reg_predicted_Y))
# Out:
# Coefficients (a,b,c,..) :  [('SOG', array([ -7.49958771e-03,   1.75916602e-04,   4.02862933e-04,
#         -6.90547865e-04,  -5.61602941e-09,  -3.56415181e-03,
#         -7.64848907e-06]))]
# Mean squared error: 0.30307
# Variance : -0.01491

# %%
selina_pred_df = longitude_linear_reg_test_X

# %%
selina_pred_df['longitude'] = pd.DataFrame(longitude_linear_reg_predicted_Y)
selina_pred_df['latitude'] = pd.DataFrame(latitude_linear_reg_predicted_Y)
# Out:
# /Users/yashunavetia/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /Users/yashunavetia/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
dff = pd.core.frame.DataFrame
ships = dff({'count' : selina_pred_df.groupby( [ "VoyageID"] ).size()}).reset_index()
ships_sorted = ships.sort_values(by=["count"], ascending=False)
ships_sorted
# Out:
#       VoyageID   count
# 32          33  126593
# 17          18  113948
# 97          98  107672
# 24          25  102861
# 93          94   95873
# 18          19   88034
# 38          39   87294
# 46          47   86757
# 98          99   86155
# 39          40   85600
# 15          16   85393
# 35          36   84333
# 13          14   83939
# 53          54   81923
# 54          55   79271
# 27          28   78750
# 73          74   78655
# 90          91   77893
# 125        126   74479
# 36          37   73298
# 101        102   73268
# 2            3   71035
# 81          82   70300
# 7            8   68799
# 60          61   68158
# 428        429   68088
# 110        111   67420
# 108        109   66391
# 115        116   63994
# 117        118   63813
# ...        ...     ...
# 3564      4765       1
# 4209      5645       1
# 4550      6085       1
# 4211      5647       1
# 3602      4830       1
# 3608      4843       1
# 4524      6052       1
# 4870      6553       1
# ...

# %%
selina_pred_df = selina_pred_df[selina_pred_df["VoyageID"] == 55 ]
selina_pred_df_sorted = selina_pred_df.sort_values(by=["Timestamp"])
selina_pred_df_sorted.to_csv("predicted55.csv")

# %%
test_copy = test

# %%
test_copy = test_copy[test_copy["VoyageID"] == 55]
test_copy_sorted = test_copy.sort_values(by=["Timestamp"])
test_copy_sorted.to_csv("actual55.csv")

# %%
test_copy.shape
# Out:
# (79271, 12)

# %%
selina_pred_df_sorted.shape
# Out:
# (79271, 9)

# %%
speedCols= {'SOG':longitude_linear_reg_test_X['SOG'],'VoyageID':longitude_linear_reg_test_X['VoyageID']}
speed_df = pd.DataFrame(speedCols)

# %%
speed_df.shape
# Out:
# (15904199, 2)

# %%
#calculating the mean of the SOG per ID basis
speed_df_groupby = speed_df.groupby('VoyageID', as_index=False)['SOG'].mean()

# %%
speed_df_groupby_sorted = speed_df_groupby.sort_values(by=["SOG"], ascending=False)
speed_df_groupby_sorted1 =
# Out:
#       VoyageID         SOG
# 712        718  102.300003
# 4344      5809  102.300003
# 3525      4679  102.300003
# 1793      2353  102.300003
# 2096      2827  102.199997
# 909        964   98.639173
# 3091      4091   65.959212
# 4774      6441   56.358778
# 3768      5084   53.585793
# 1845      2442   51.299999
# 300        301   45.449567
# 1913      2586   25.650001
# 270        271   25.469937
# 4948      6674   25.400000
# 4527      6055   24.200001
# 94          95   23.693350
# 2340      3139   21.900000
# 126        127   21.375981
# 4551      6086   20.927333
# 3233      4323   20.657747
# 4319      5777   20.500000
# 3251      4344   20.448691
# 1698      2161   20.391786
# 851        890   20.384259
# 3087      4086   20.220455
# 4607      6170   20.202941
# 4205      5641   20.129565
# 3343      4469   20.122472
# 2151      2899   20.000000
# 4028      5420   19.928418
# ...        ...         ...
# 4550      6085    0.000000
# 4552      6087    0.000000
# ...

# %%
temp = speed_df_groupby_sorted[speed_df_groupby_sorted["VoyageID"] == 118]
temp
# Out:
#      VoyageID      SOG
# 117       118  1.35067

# %%
from sklearn.neural_network import MLPClassifier

nn = MLPClassifier(solver='lbfgs', alpha=1e-5, hidden_layer_sizes=(4, 3))
#nn_train_X, nn_cross_valid_X , nn_train_Y, nn_cross_valid_Y = train_test_split(train_X, train_Y, test_size=0.2, random_state=12)

nn.fit(latitude_linear_reg_train_X, latitude_linear_reg_train_Y)
predicted_Y_nn = nn.predict(latitude_linear_reg_test_X)
# Out:
# /Users/yashunavetia/anaconda/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:912: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-132-dc2e4cc1c6cd> in <module>()
#       4 #nn_train_X, nn_cross_valid_X , nn_train_Y, nn_cross_valid_Y = train_test_split(train_X, train_Y, test_size=0.2, random_state=12)
#       5
# ----> 6 nn.fit(latitude_linear_reg_train_X, latitude_linear_reg_train_Y)
#       7 predicted_Y_nn = nn.predict(latitude_linear_reg_test_X)
#
# /Users/yashunavetia/anaconda/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py in fit(self, X, y)
#     971         """
# ...

# %%
from xgboost import XGBRegressor
xgb = XGBRegressor()
xgb.fit(latitude_linear_reg_train_X,latitude_linear_reg_train_Y)
latitude_XGB_Y_pred = xgb.predict(latitude_linear_reg_test_X)
print("Mean squared error: %.12f"
      % mean_squared_error(latitude_linear_reg_test_Y,latitude_XGB_Y_pred))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-135-51b7eee90819> in <module>()
#       1 from xgboost import XGBRegressor
#       2 xgb = XGBRegressor()
# ----> 3 xgb.fit(latitude_linear_reg_train_X,latitude_linear_reg_train_Y)
#       4 latitude_XGB_Y_pred = xgb.predict(latitude_linear_reg_test_X)
#       5 print("Mean squared error: %.12f"
#
# /Users/yashunavetia/anaconda/lib/python3.6/site-packages/xgboost/sklearn.py in fit(self, X, y, eval_set, eval_metric, early_stopping_rounds, verbose)
#     220             metric measured on the validation set to stderr.
#     221         """
# --> 222         trainDmatrix = DMatrix(X, label=y, missing=self.missing)
#     223
#     224         evals_result = {}
#
# ...

# %%
from sklearn import tree
dtree = tree.DecisionTreeRegressor()
dtree.fit(latitude_linear_reg_train_X,latitude_linear_reg_train_Y)
latitude_tree_Y_pred = dtree.predict(latitude_linear_reg_test_X)
print("Mean squared error: %.12f"
      % mean_squared_error(latitude_linear_reg_test_Y,latitude_tree_Y_pred))
# Out:
# Mean squared error: 0.728364242955

# %%
from sklearn import tree
dtree = tree.DecisionTreeRegressor()
dtree.fit(longitude_linear_reg_train_X,longitude_linear_reg_train_Y)
longitude_tree_Y_pred = dtree.predict(longitude_linear_reg_test_X)
print("Mean squared error: %.12f"
      % mean_squared_error(longitude_linear_reg_test_Y,longitude_tree_Y_pred))
# Out:
# Mean squared error: 0.544701450837

# %%
from xgboost import XGBRegressor
xgb = XGBRegressor()
xgb.fit(longitude_linear_reg_train_X,longitude_linear_reg_train_Y)
longitude_XGB_Y_pred = xgb.predict(longitude_linear_reg_test_X)
print("Mean squared error: %.12f"
      % mean_squared_error(longitude_XGB_Y_pred, longitude_linear_reg_test_Y))

# %%
selina_tree_df = longitude_linear_reg_test_X
selina_tree_df['longitude'] = pd.DataFrame(longitude_tree_Y_pred)
selina_tree_df['latitude'] = pd.DataFrame(latitude_tree_Y_pred)
selina_tree_df = selina_tree_df[selina_tree_df["VoyageID"] == 964]
selina_tree_df_sorted = selina_tree_df.sort_values(by=["longitude"])
selina_tree_df_sorted.to_csv("predictedTreeLL964.csv")
test_copy1 = test
test_copy1 = test_copy1[test_copy1["VoyageID"] == 964]
test_copy_sorted1 = test_copy1.sort_values(by=["Timestamp"])
test_copy_sorted1.to_csv("actualTree964.csv")
# Out:
# /Users/yashunavetia/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/yashunavetia/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
mm = speed_df_groupby_sorted

# %%
mm = mm[mm['SOG'] <1.5]

# %%
mm = mm[mm['SOG'] <1]

# %%
mm
# Out:
#       VoyageID       SOG
# 269        270  0.994180
# 149        150  0.992252
# 372        373  0.990571
# 4773      6439  0.984427
# 1495      1819  0.980982
# 243        244  0.978049
# 917        972  0.977482
# 92          93  0.976253
# 233        234  0.976204
# 1926      2603  0.975470
# 3668      4947  0.975168
# 1177      1299  0.973529
# 185        186  0.964704
# 275        276  0.960044
# 584        588  0.959526
# 2198      2954  0.957016
# 3845      5190  0.954167
# 3656      4930  0.951724
# 2921      3855  0.951613
# 2957      3893  0.947268
# 2579      3437  0.944887
# 167        168  0.943128
# 392        393  0.940929
# 60          61  0.937922
# 2089      2814  0.936813
# 390        391  0.931872
# 1923      2599  0.931480
# 340        341  0.931077
# 2524      3362  0.930189
# 655        661  0.929367
# ...        ...       ...
# 4550      6085  0.000000
# 4552      6087  0.000000
# 4554      6089  0.000000
# 4555      6090  0.000000
# 4525      6053  0.000000
# ...

# %%
mm = mm[mm['SOG'] <0.5]
mm
# Out:
#       VoyageID       SOG
# 194        195  0.498812
# 171        172  0.495166
# 1256      1413  0.493123
# 206        207  0.490033
# 3406      4536  0.488451
# 645        651  0.487775
# 613        619  0.485825
# 54          55  0.482300
# 152        153  0.478605
# 31          32  0.477127
# 2175      2926  0.470111
# 1789      2349  0.457458
# 2629      3500  0.455136
# 984       1053  0.454999
# 256        257  0.448963
# 97          98  0.448153
# 57          58  0.446041
# 2118      2853  0.444627
# 4            5  0.444460
# 13          14  0.444400
# 4434      5917  0.443053
# 297        298  0.441563
# 138        139  0.439243
# 289        290  0.437811
# 3268      4369  0.436987
# 2491      3321  0.436942
# 4109      5509  0.434568
# 3328      4448  0.434178
# 221        222  0.432884
# 860        901  0.430339
# ...        ...       ...
# 4550      6085  0.000000
# 4552      6087  0.000000
# 4554      6089  0.000000
# 4555      6090  0.000000
# 4525      6053  0.000000
# ...

# %%
mm = mm[mm['SOG'] <0.3]
mm
# Out:
#       VoyageID       SOG
# 157        158  0.297640
# 33          34  0.285967
# 2423      3244  0.282639
# 65          66  0.281738
# 5074      7025  0.280952
# 250        251  0.278856
# 4702      6320  0.278652
# 3933      5317  0.275043
# 208        209  0.271408
# 193        194  0.271382
# 24          25  0.270269
# 15          16  0.269501
# 1422      1706  0.266314
# 204        205  0.262887
# 81          82  0.258953
# 1336      1540  0.250000
# 130        131  0.247748
# 22          23  0.245461
# 238        239  0.241694
# 230        231  0.236645
# 294        295  0.235934
# 1208      1338  0.235618
# 1981      2678  0.232489
# 2420      3241  0.232238
# 4425      5905  0.231843
# 195        196  0.230846
# 4221      5660  0.230000
# 2365      3170  0.229571
# 4213      5649  0.222230
# 207        208  0.220342
# ...        ...       ...
# 4550      6085  0.000000
# 4552      6087  0.000000
# 4554      6089  0.000000
# 4555      6090  0.000000
# 4525      6053  0.000000
# ...
